# %% [markdown]
# ## Donut

# %% [markdown]
# ### Data Preprocessing

# %% [markdown]
# Donut desires folloling Data Structure:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Create that Structure

# %%
import os
import json
import shutil
import random
from tqdm.notebook import tqdm

# %% [markdown]
# Create ~150 train examples

# %%
dir = "/home/sebastian/Documents/Hauptprojekt/Daten_Donut.nosync/train/"
for f in os.listdir(dir):
    os.remove(os.path.join(dir, f))

lines = []
images = []

all_images = os.listdir("/home/sebastian/Documents/Hauptprojekt/Daten.nosync/data/docile/annotations/")
random.shuffle(all_images)
counter = 0
for ann in tqdm(all_images):
    if counter == 150:
        break
    if ann != ".ipynb_checkpoints":
        with open("/home/sebastian/Documents/Hauptprojekt/Daten.nosync/data/docile/annotations/" + ann) as f:
            data = json.load(f)
    if data["metadata"]["page_count"] == 1:
        page = data["metadata"]["page_count"]
        images.append(ann[:-5] + "(" + str(page) + ")" + ".jpg")
        line = {"gt_parse": data}
        lines.append(line)
        counter+=1
#print(lines)
print(len(images))
with open("/home/sebastian/Documents/Hauptprojekt/Daten_Donut.nosync/train/metadata.jsonl", 'w') as f:
    for i, gt_parse in enumerate(lines):
        line = {"file_name": images[i], "ground_truth": json.dumps(gt_parse)}
        f.write(json.dumps(line) + "\n")
        shutil.copyfile("/home/sebastian/Documents/Hauptprojekt/Daten.nosync/data/docile/jpgs/" + images[i], "/home/sebastian/Documents/Hauptprojekt/Daten_Donut.nosync/train/" + images[i])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[15], line 2
#       1 dir = "/Daten_Donut.nosync/train/"
# ----> 2 for f in os.listdir(dir):
#       3     os.remove(os.path.join(dir, f))
#       5 lines = []
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Daten_Donut.nosync/train/'

# %% [markdown]
# create ~30 test examples

# %%
dir = "/home/sebastian/Documents/Hauptprojekt/Daten_Donut.nosync/test/"
for f in os.listdir(dir):
    os.remove(os.path.join(dir, f))

lines = []
images = []
    
all_images = os.listdir("/home/sebastian/Documents/Hauptprojekt/Daten.nosync/data/docile/annotations/")
random.shuffle(all_images)
counter = 0
for ann in tqdm(all_images):
    if counter == 30:
        break
    if ann != ".ipynb_checkpoints":
        with open("/home/sebastian/Documents/Hauptprojekt/Daten.nosync/data/docile/annotations/" + ann) as f:
            data = json.load(f)
    if data["metadata"]["page_count"] == 1:
        page = data["metadata"]["page_count"]
        images.append(ann[:-5] + "(" + str(page) + ")" + ".jpg")
        line = {"gt_parse": data}
        lines.append(line)
        counter+=1
#print(lines)
print(len(images))
with open("/home/sebastian/Documents/Hauptprojekt/Daten_Donut.nosync/test/metadata.jsonl", 'w') as f:
    for i, gt_parse in enumerate(lines):
        line = {"file_name": images[i], "ground_truth": json.dumps(gt_parse)}
        f.write(json.dumps(line) + "\n")
        shutil.copyfile("/home/sebastian/Documents/Hauptprojekt/Daten.nosync/data/docile/jpgs/" + images[i], "/home/sebastian/Documents/Hauptprojekt/Daten_Donut.nosync/test/" + images[i])
# Out:
#   0%|          | 0/105684 [00:00<?, ?it/s]
# 30

# %% [markdown]
# create ~30 validation exapmles

# %%
dir = "/home/sebastian/Documents/Hauptprojekt/Daten_Donut.nosync/val/"
for f in os.listdir(dir):
    os.remove(os.path.join(dir, f))
    
lines = []
images = []

all_images = os.listdir("/home/sebastian/Documents/Hauptprojekt/Daten.nosync/data/docile/annotations/")
random.shuffle(all_images)
counter = 0
for ann in tqdm(all_images):
    if counter == 30:
        break
    if ann != ".ipynb_checkpoints":
        with open("/home/sebastian/Documents/Hauptprojekt/Daten.nosync/data/docile/annotations/" + ann) as f:
            data = json.load(f)
    if data["metadata"]["page_count"] == 1:
        page = data["metadata"]["page_count"]
        images.append(ann[:-5] + "(" + str(page) + ")" + ".jpg")
        line = {"gt_parse": data}
        lines.append(line)
        counter+=1
#print(lines)
print(len(images))
with open("/home/sebastian/Documents/Hauptprojekt/Daten_Donut.nosync/val/metadata.jsonl", 'w') as f:
    for i, gt_parse in enumerate(lines):
        line = {"file_name": images[i], "ground_truth": json.dumps(gt_parse)}
        f.write(json.dumps(line) + "\n")
        shutil.copyfile("/home/sebastian/Documents/Hauptprojekt/Daten.nosync/data/docile/jpgs/" + images[i], "/home/sebastian/Documents/Hauptprojekt/Daten_Donut.nosync/val/" + images[i])
# Out:
#   0%|          | 0/105684 [00:00<?, ?it/s]
# 30
